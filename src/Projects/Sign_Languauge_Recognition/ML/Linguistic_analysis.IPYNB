# %%
# Plan 

#Import full sentence videos jsons
# Clustering ML for simaler signs with simaler hamnosys

# %%
import pandas as pd 
import json
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = json.path.join("..", "DATA/Annotated")

for path in os.listdir(Data):
    with open(os.path.join(Data, path)) as f:
        if path.endwith(".json"):
            data = json.load(f)
        else:
            continue
